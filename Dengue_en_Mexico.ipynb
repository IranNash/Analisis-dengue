# %% [markdown]
# <a href="https://colab.research.google.com/github/IranNash/Analisis-dengue/blob/main/Dengue_en_Mexico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## IMPORTAR DATOS

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/IranNash/Analisis-dengue/refs/heads/main/dengue_abierto.csv')
df.head()
df.shape[0]
# Out:
# 215002

# %% [markdown]
# ## ANALISIS DESCRIPTIVO

# %%
df.describe()
# Out:
#         ID_REGISTRO           SEXO      EDAD_ANOS    ENTIDAD_RES  \
# count  2.150020e+05  215002.000000  215002.000000  215002.000000
# mean   1.419445e+06       1.454917      28.804909      17.209175
# std    7.326374e+04       0.497965      18.489258       7.117987
# min    8.491130e+05       1.000000       0.000000       1.000000
# 25%    1.361075e+06       1.000000      14.000000      12.000000
# 50%    1.419254e+06       1.000000      26.000000      17.000000
# 75%    1.476196e+06       2.000000      41.000000      21.000000
# max    1.370460e+07       2.000000     140.000000      35.000000
#
#        MUNICIPIO_RES  HABLA_LENGUA_INDIG       INDIGENA  ENTIDAD_UM_NOTIF  \
# count  215002.000000       215002.000000  215002.000000     215002.000000
# mean       57.032335            1.981623       1.977577         17.201691
# std        87.190327            0.134309       0.148055          7.118288
# min         1.000000            1.000000       1.000000          1.000000
# ...
